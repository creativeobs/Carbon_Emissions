# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
#import libraries

import numpy as np
import pandas as pd
import os

# %% [markdown]
# ### Check files and directory

# %%
pwd
# Out:
# 'C:\\Users\\rurue\\deswcana_proj'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'assets',
#  'clean_dataset_co2.csv',
#  'dashboard.py',
#  'Data Cleaning.ipynb',
#  'Data Processing and Visualization.ipynb',
#  'fossil-fuel-co2-emissions-by-nation.csv']

# %%
df = pd.read_csv('fossil-fuel-co2-emissions-by-nation.csv')
df
# Out:
#        Year                    Country  Total  Solid Fuel  Liquid Fuel  \
# 0      1751             UNITED KINGDOM   2552        2552            0
# 1      1752             UNITED KINGDOM   2553        2553            0
# 2      1753             UNITED KINGDOM   2553        2553            0
# 3      1754             UNITED KINGDOM   2554        2554            0
# 4      1755             UNITED KINGDOM   2555        2555            0
# ...     ...                        ...    ...         ...          ...
# 17227  2014                   VIET NAM  45517       19246        12694
# 17228  2014  WALLIS AND FUTUNA ISLANDS      6           0            6
# 17229  2014                      YEMEN   6190         137         5090
# 17230  2014                     ZAMBIA   1228         132          797
# 17231  2014                   ZIMBABWE   3278        2097         1005
#
#        Gas Fuel  Cement  Gas Flaring  Per Capita  Bunker fuels (Not in Total)
# ...

# %% [markdown]
# ### Check information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17232 entries, 0 to 17231
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         17232 non-null  int64
#  1   Country                      17232 non-null  object
#  2   Total                        17232 non-null  int64
#  3   Solid Fuel                   17232 non-null  int64
#  4   Liquid Fuel                  17232 non-null  int64
#  5   Gas Fuel                     17232 non-null  int64
#  6   Cement                       17232 non-null  int64
#  7   Gas Flaring                  17232 non-null  int64
#  8   Per Capita                   17232 non-null  float64
#  9   Bunker fuels (Not in Total)  17232 non-null  int64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 1.3+ MB

# %%
df.describe(include= 'all').T
# Out:
#                                count unique             top freq  \
# Year                         17232.0    NaN             NaN  NaN
# Country                        17232    256  UNITED KINGDOM  264
# Total                        17232.0    NaN             NaN  NaN
# Solid Fuel                   17232.0    NaN             NaN  NaN
# Liquid Fuel                  17232.0    NaN             NaN  NaN
# Gas Fuel                     17232.0    NaN             NaN  NaN
# Cement                       17232.0    NaN             NaN  NaN
# Gas Flaring                  17232.0    NaN             NaN  NaN
# Per Capita                   17232.0    NaN             NaN  NaN
# Bunker fuels (Not in Total)  17232.0    NaN             NaN  NaN
#
#                                      mean            std     min     25%  \
# Year                          1961.579561      44.251691  1751.0  1944.0
# Country                               NaN            NaN     NaN     NaN
# ...

# %% [markdown]
# ### renaming columns

# %%
cols = ['Year', 'Country', 'Total Carbon Emission', 'Solid Fuel', 'Liquid Fuel', 'Gas Fuel', 'Cement', 'Gas Flare', 'Per Capita', 'Bunker Fuels']
df.columns = cols
df
# Out:
#        Year                    Country  Total Carbon Emission  Solid Fuel  \
# 0      1751             UNITED KINGDOM                   2552        2552
# 1      1752             UNITED KINGDOM                   2553        2553
# 2      1753             UNITED KINGDOM                   2553        2553
# 3      1754             UNITED KINGDOM                   2554        2554
# 4      1755             UNITED KINGDOM                   2555        2555
# ...     ...                        ...                    ...         ...
# 17227  2014                   VIET NAM                  45517       19246
# 17228  2014  WALLIS AND FUTUNA ISLANDS                      6           0
# 17229  2014                      YEMEN                   6190         137
# 17230  2014                     ZAMBIA                   1228         132
# 17231  2014                   ZIMBABWE                   3278        2097
#
#        Liquid Fuel  Gas Fuel  Cement  Gas Flare  Per Capita  Bunker Fuels
# ...

# %% [markdown]
# ### check all unique values

# %%
def show_all_unique_value(df):
    print(df.unique())

columns = df.columns

for x in columns:
    show_all_unique_value(df[x])
    print('-'*100)
# Out:
# [1751 1752 1753 1754 1755 1756 1757 1758 1759 1760 1761 1762 1763 1764
#  1765 1766 1767 1768 1769 1770 1771 1772 1773 1774 1775 1776 1777 1778
#  1779 1780 1781 1782 1783 1784 1785 1786 1787 1788 1789 1790 1791 1792
#  1793 1794 1795 1796 1797 1798 1799 1800 1801 1802 1803 1804 1805 1806
#  1807 1808 1809 1810 1811 1812 1813 1814 1815 1816 1817 1818 1819 1820
#  1821 1822 1823 1824 1825 1826 1827 1828 1829 1830 1831 1832 1833 1834
#  1835 1836 1837 1838 1839 1840 1841 1842 1843 1844 1845 1846 1847 1848
#  1849 1850 1851 1852 1853 1854 1855 1856 1857 1858 1859 1860 1861 1862
#  1863 1864 1865 1866 1867 1868 1869 1870 1871 1872 1873 1874 1875 1876
#  1877 1878 1879 1880 1881 1882 1883 1884 1885 1886 1887 1888 1889 1890
#  1891 1892 1893 1894 1895 1896 1897 1898 1899 1900 1901 1902 1903 1904
#  1905 1906 1907 1908 1909 1910 1911 1912 1913 1914 1915 1916 1917 1918
#  1919 1920 1921 1922 1923 1924 1925 1926 1927 1928 1929 1930 1931 1932
# ...

# %% [markdown]
# ### check null values

# %%
df.isna().sum()
# Out:
# Year                     0
# Country                  0
# Total Carbon Emission    0
# Solid Fuel               0
# Liquid Fuel              0
# Gas Fuel                 0
# Cement                   0
# Gas Flare                0
# Per Capita               0
# Bunker Fuels             0
# dtype: int64

# %%
### stripping unwanted characters

# %%
def update_cols(c):
    x = c.find('(')
    return c[0:x-1].capitalize().strip() if x > 1 else c.capitalize().strip()

# %%
df['Country'] = df['Country'].apply(update_cols)

# %%
df['Country'].unique()
# Out:
# array(['United kingdom', 'Canada', 'Germany', 'Poland',
#        'United states of america', 'Belgium', 'France', 'Austria',
#        'Norway', 'Hungary', 'Spain', 'Ussr', 'Sweden', 'Denmark',
#        'Netherlands', 'Ireland', 'Australia', 'Romania', 'India',
#        'Switzerland', 'Czechoslovakia', 'Finland', 'Italy', 'Turkey',
#        'Greece', 'Japan', 'Portugal', 'New zealand', 'Bulgaria',
#        'Yugoslavia', 'Peru', 'South africa', 'Argentina', 'Indonesia',
#        'Peninsular malaysia', 'Mexico', 'Viet nam', 'Chile', 'Taiwan',
#        'China', 'Algeria', 'Brazil', 'Islamic republic of iran',
#        'Zimbabwe', 'Venezuela', 'United korea', 'Philippines',
#        'Trinidad and tobago', 'Egypt', 'Nigeria', 'Tunisia', 'Ecuador',
#        'Democratic republic of the congo', 'Puerto rico', 'Colombia',
#        'Iraq', 'Sarawak', 'Netherland antilles and aruba', 'Mozambique',
#        'Barbados', 'Estonia', 'French indo-china', 'Latvia', 'Morocco',
# ...

# %%
df
# Out:
#        Year                    Country  Total Carbon Emission  Solid Fuel  \
# 0      1751             United kingdom                   2552        2552
# 1      1752             United kingdom                   2553        2553
# 2      1753             United kingdom                   2553        2553
# 3      1754             United kingdom                   2554        2554
# 4      1755             United kingdom                   2555        2555
# ...     ...                        ...                    ...         ...
# 17227  2014                   Viet nam                  45517       19246
# 17228  2014  Wallis and futuna islands                      6           0
# 17229  2014                      Yemen                   6190         137
# 17230  2014                     Zambia                   1228         132
# 17231  2014                   Zimbabwe                   3278        2097
#
#        Liquid Fuel  Gas Fuel  Cement  Gas Flare  Per Capita  Bunker Fuels
# ...

# %%
df[(df['Year'] >= int('1750')) & (df['Year'] <= int('2000'))]
# Out:
#        Year         Country  Total Carbon Emission  Solid Fuel  Liquid Fuel  \
# 0      1751  United kingdom                   2552        2552            0
# 1      1752  United kingdom                   2553        2553            0
# 2      1753  United kingdom                   2553        2553            0
# 3      1754  United kingdom                   2554        2554            0
# 4      1755  United kingdom                   2555        2555            0
# ...     ...             ...                    ...         ...          ...
# 14185  2000        Viet nam                  14629        5654         6330
# 14186  2000           Yemen                   3993           0         3803
# 14187  2000      Yugoslavia                  11225        8840         1139
# 14188  2000          Zambia                    497          79          366
# 14189  2000        Zimbabwe                   3797        2763          898
#
# ...

# %%
c = df.groupby(['Country', 'Year']).sum().reset_index()

# %%
c = df.sort_values(['Year'])
c['Year'] = c['Year'].astype('str')

# %%
c
# Out:
#        Year         Country  Total Carbon Emission  Solid Fuel  Liquid Fuel  \
# 0      1751  United kingdom                   2552        2552            0
# 1      1752  United kingdom                   2553        2553            0
# 2      1753  United kingdom                   2553        2553            0
# 3      1754  United kingdom                   2554        2554            0
# 4      1755  United kingdom                   2555        2555            0
# ...     ...             ...                    ...         ...          ...
# 17088  2014           Ghana                   3945           0         3188
# 17089  2014       Gibraltar                    144           0          144
# 17090  2014          Greece                  18358        7203         8906
# 17079  2014            Fiji                    319           0          293
# 17231  2014        Zimbabwe                   3278        2097         1005
#
# ...

# %%
df.groupby(['Country', 'Year']).sum()
# Out:
#                   Total Carbon Emission  Solid Fuel  Liquid Fuel  Gas Fuel  \
# Country     Year
# Afghanistan 1949                      4           4            0         0
#             1950                     23           6           18         0
#             1951                     25           7           18         0
#             1952                     25           9           17         0
#             1953                     29          10           18         0
# ...                                 ...         ...          ...       ...
# Zimbabwe    2010                   2121        1531          481         0
#             2011                   2608        1584          888         0
#             2012                   2125         917         1006         0
#             2013                   3184        1902         1119         0
#             2014                   3278        2097         1005         0
#
# ...

# %%
len(df['Country'].unique())
# Out:
# 254

# %%
df
# Out:
#        Year                    Country  Total Carbon Emission  Solid Fuel  \
# 0      1751             United kingdom                   2552        2552
# 1      1752             United kingdom                   2553        2553
# 2      1753             United kingdom                   2553        2553
# 3      1754             United kingdom                   2554        2554
# 4      1755             United kingdom                   2555        2555
# ...     ...                        ...                    ...         ...
# 17227  2014                   Viet nam                  45517       19246
# 17228  2014  Wallis and futuna islands                      6           0
# 17229  2014                      Yemen                   6190         137
# 17230  2014                     Zambia                   1228         132
# 17231  2014                   Zimbabwe                   3278        2097
#
#        Liquid Fuel  Gas Fuel  Cement  Gas Flare  Per Capita  Bunker Fuels
# ...

# %%
df
# Out:
#        Year                    Country  Total Carbon Emission  Solid Fuel  \
# 0      1751             United kingdom                   2552        2552
# 1      1752             United kingdom                   2553        2553
# 2      1753             United kingdom                   2553        2553
# 3      1754             United kingdom                   2554        2554
# 4      1755             United kingdom                   2555        2555
# ...     ...                        ...                    ...         ...
# 17227  2014                   Viet nam                  45517       19246
# 17228  2014  Wallis and futuna islands                      6           0
# 17229  2014                      Yemen                   6190         137
# 17230  2014                     Zambia                   1228         132
# 17231  2014                   Zimbabwe                   3278        2097
#
#        Liquid Fuel  Gas Fuel  Cement  Gas Flare  Per Capita  Bunker Fuels
# ...

# %%
c = pd.DataFrame()

# %%
c.append
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def insert_to_countries(x):
    
    for i, c in enumerate(df['Country'].unique()):
        if x == c:
            return emp[i]

# %%
df['locations'] = df['Country'].apply(insert_to_countries)

# %%
df

# %%
df[['lat','lon']] = pd.DataFrame(df['locations'].tolist(),index=df.index)

# %%
df

# %%
df['scaled'] = df['Total Carbon Emission'].apply(lambda x: abs(int(x)))
df[df['scaled'] < 0]

# %%
df.columns

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="my_Dashboard")
import numpy as np

countries = df['Country'].unique()
emp = []

for x in countries:
    try:
        loc = geolocator.geocode(x)
        emp.append((loc.latitude, loc.longitude))
    except:
        emp.append(np.nan)

# %%
x

# %%
x = x.groupby('Country').sum().sort_values('Solid Fuel', ascending=False).head(5)

# %% [markdown]
# ### Save clean Dataset

# %%
df.to_csv('clean_dataset_co2.csv', index=False)
